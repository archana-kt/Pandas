# %% [markdown]
# # Group by

# %%
# Extract the data belongs to brazil with key factors are female from IT department

# %%
import pandas as pd

# %%
data = pd.read_excel("/Users/archanaqueen/Desktop/i18n/Daily Class/Pandas/Dataset_work/Employee Sample Data.xlsx")

# %%
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
data.head()
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# ...

# %%
data.tail()
# Out:
#        EEID     Full Name       Job Title  Department        Business Unit  \
# 995  E03094  Wesley Young     Sr. Analyst   Marketing  Speciality Products
# 996  E01909  Lillian Khan         Analyst     Finance  Speciality Products
# 997  E04398   Oliver Yang        Director   Marketing  Speciality Products
# 998  E02521   Lily Nguyen     Sr. Analyst     Finance  Speciality Products
# 999  E03545   Sofia Cheng  Vice President  Accounting            Corporate
#
#      Gender  Ethnicity  Age  Hire Date  Annual Salary  Bonus %        Country  \
# 995    Male  Caucasian   33 2016-09-18          98427     0.00  United States
# 996  Female      Asian   44 2010-05-31          47387     0.00          China
# 997    Male      Asian   31 2019-06-10         176710     0.15  United States
# 998  Female      Asian   33 2012-01-28          95960     0.00          China
# 999  Female      Asian   63 2020-07-26         216195     0.31  United States
#
#          City  Exit Date
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   Job Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Business Unit  1000 non-null   object
#  5   Gender         1000 non-null   object
#  6   Ethnicity      1000 non-null   object
#  7   Age            1000 non-null   int64
#  8   Hire Date      1000 non-null   datetime64[ns]
#  9   Annual Salary  1000 non-null   int64
#  10  Bonus %        1000 non-null   float64
#  11  Country        1000 non-null   object
#  12  City           1000 non-null   object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 109.5+ KB

# %%
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   Job Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Business Unit  1000 non-null   object
#  5   Gender         1000 non-null   object
#  6   Ethnicity      1000 non-null   object
#  7   Age            1000 non-null   int64
#  8   Hire Date      1000 non-null   datetime64[ns]
#  9   Annual Salary  1000 non-null   int64
#  10  Bonus %        1000 non-null   float64
#  11  Country        1000 non-null   object
#  12  City           1000 non-null   object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 622.2 KB

# %%
data.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
data['Job Title']
# Out:
# 0                    Sr. Manger
# 1           Technical Architect
# 2                      Director
# 3      Computer Systems Manager
# 4                   Sr. Analyst
#                  ...
# 995                 Sr. Analyst
# 996                     Analyst
# 997                    Director
# 998                 Sr. Analyst
# 999              Vice President
# Name: Job Title, Length: 1000, dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['EEID'])
# Out:
# pandas.core.series.Series

# %%
data.dtypes
# Out:
# EEID                     object
# Full Name                object
# Job Title                object
# Department               object
# Business Unit            object
# Gender                   object
# Ethnicity                object
# Age                       int64
# Hire Date        datetime64[ns]
# Annual Salary             int64
# Bonus %                 float64
# Country                  object
# City                     object
# Exit Date        datetime64[ns]
# dtype: object

# %%
x = data.groupby("Country")

# %%
x

# %%
x.get_group("Brazil")
# Out:
#        EEID        Full Name             Job Title       Department  \
# 20   E03680   Elias Alvarado            Sr. Manger               IT
# 22   E03484     Logan Rivera              Director               IT
# 26   E04545    Abigail Mejia      Quality Engineer      Engineering
# 31   E00402   Dominic Guzman               Analyst          Finance
# 39   E01417        Leah Pena  Enterprise Architect               IT
# ..      ...              ...                   ...              ...
# 950  E02888     Elijah Ramos            Sr. Manger               IT
# 955  E02561  Samantha Vargas              Director  Human Resources
# 968  E02221   Julian Delgado       Systems Analyst               IT
# 970  E02627     Parker Avila            Analyst II        Marketing
# 991  E03430      Leo Herrera  Sr. Business Partner  Human Resources
#
#               Business Unit  Gender Ethnicity  Age  Hire Date  Annual Salary  \
# ...

# %%
brdf = x.get_group("Brazil")

# %%
brdf.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
brdf[(brdf['Gender']=='Female') & (brdf['Department']=='IT')]
# Out:
#        EEID         Full Name                       Job Title Department  \
# 39   E01417         Leah Pena            Enterprise Architect         IT
# 60   E00699         Ava Ayala                      Sr. Manger         IT
# 87   E03440   Genesis Navarro  Cloud Infrastructure Architect         IT
# 88   E00431   Eliza Hernandez               Network Architect         IT
# 97   E04931        Zoe Romero               Network Architect         IT
# 269  E01525    Charlotte Ruiz        Computer Systems Manager         IT
# 386  E01241   Hadley Guerrero                      Sr. Manger         IT
# 624  E01432      Peyton Garza                 Systems Analyst         IT
# 705  E02192        Lucy Avila             Solutions Architect         IT
# 731  E01649      Eva Alvarado        Computer Systems Manager         IT
# 825  E00035  Lillian Gonzales  Cloud Infrastructure Architect         IT
# 886  E00102       Riley Rojas               Network Architect         IT
#
# ...

# %%
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
data.set_index("Country",inplace=True)

# %%
data
# Out:
#                  EEID        Full Name                 Job Title  Department  \
# Country
# United States  E02387      Emily Davis                Sr. Manger          IT
# China          E04105    Theodore Dinh       Technical Architect          IT
# United States  E02572     Luna Sanders                  Director     Finance
# United States  E02832  Penelope Jordan  Computer Systems Manager          IT
# United States  E01639        Austin Vo               Sr. Analyst     Finance
# ...               ...              ...                       ...         ...
# United States  E03094     Wesley Young               Sr. Analyst   Marketing
# China          E01909     Lillian Khan                   Analyst     Finance
# United States  E04398      Oliver Yang                  Director   Marketing
# China          E02521      Lily Nguyen               Sr. Analyst     Finance
# United States  E03545      Sofia Cheng            Vice President  Accounting
#
# ...

# %% [markdown]
# # Another method like set_index

# %%
data.xs("Brazil")
# Out:
#            EEID        Full Name             Job Title       Department  \
# Country
# Brazil   E03680   Elias Alvarado            Sr. Manger               IT
# Brazil   E03484     Logan Rivera              Director               IT
# Brazil   E04545    Abigail Mejia      Quality Engineer      Engineering
# Brazil   E00402   Dominic Guzman               Analyst          Finance
# Brazil   E01417        Leah Pena  Enterprise Architect               IT
# ...         ...              ...                   ...              ...
# Brazil   E02888     Elijah Ramos            Sr. Manger               IT
# Brazil   E02561  Samantha Vargas              Director  Human Resources
# Brazil   E02221   Julian Delgado       Systems Analyst               IT
# Brazil   E02627     Parker Avila            Analyst II        Marketing
# Brazil   E03430      Leo Herrera  Sr. Business Partner  Human Resources
#
#                   Business Unit  Gender Ethnicity  Age  Hire Date  \
# Country
# ...

# %%
data
# Out:
#                  EEID        Full Name                 Job Title  Department  \
# Country
# United States  E02387      Emily Davis                Sr. Manger          IT
# China          E04105    Theodore Dinh       Technical Architect          IT
# United States  E02572     Luna Sanders                  Director     Finance
# United States  E02832  Penelope Jordan  Computer Systems Manager          IT
# United States  E01639        Austin Vo               Sr. Analyst     Finance
# ...               ...              ...                       ...         ...
# United States  E03094     Wesley Young               Sr. Analyst   Marketing
# China          E01909     Lillian Khan                   Analyst     Finance
# United States  E04398      Oliver Yang                  Director   Marketing
# China          E02521      Lily Nguyen               Sr. Analyst     Finance
# United States  E03545      Sofia Cheng            Vice President  Accounting
#
# ...

# %%
data.xs("Brazil")
# Out:
#            EEID        Full Name             Job Title       Department  \
# Country
# Brazil   E03680   Elias Alvarado            Sr. Manger               IT
# Brazil   E03484     Logan Rivera              Director               IT
# Brazil   E04545    Abigail Mejia      Quality Engineer      Engineering
# Brazil   E00402   Dominic Guzman               Analyst          Finance
# Brazil   E01417        Leah Pena  Enterprise Architect               IT
# ...         ...              ...                   ...              ...
# Brazil   E02888     Elijah Ramos            Sr. Manger               IT
# Brazil   E02561  Samantha Vargas              Director  Human Resources
# Brazil   E02221   Julian Delgado       Systems Analyst               IT
# Brazil   E02627     Parker Avila            Analyst II        Marketing
# Brazil   E03430      Leo Herrera  Sr. Business Partner  Human Resources
#
#                   Business Unit  Gender Ethnicity  Age  Hire Date  \
# Country
# ...

# %%
brdf = data.xs("Brazil")

# %%
brdf.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'City', 'Exit Date'],
#       dtype='object')

# %%
brdf[(brdf['Gender']=='Female') & (brdf['Department']=='IT')]
# Out:
#            EEID         Full Name                       Job Title Department  \
# Country
# Brazil   E01417         Leah Pena            Enterprise Architect         IT
# Brazil   E00699         Ava Ayala                      Sr. Manger         IT
# Brazil   E03440   Genesis Navarro  Cloud Infrastructure Architect         IT
# Brazil   E00431   Eliza Hernandez               Network Architect         IT
# Brazil   E04931        Zoe Romero               Network Architect         IT
# Brazil   E01525    Charlotte Ruiz        Computer Systems Manager         IT
# Brazil   E01241   Hadley Guerrero                      Sr. Manger         IT
# Brazil   E01432      Peyton Garza                 Systems Analyst         IT
# Brazil   E02192        Lucy Avila             Solutions Architect         IT
# Brazil   E01649      Eva Alvarado        Computer Systems Manager         IT
# Brazil   E00035  Lillian Gonzales  Cloud Infrastructure Architect         IT
# ...

# %%
data = pd.read_excel("/Users/archanaqueen/Desktop/i18n/Daily Class/Pandas/Dataset_work/Employee Sample Data.xlsx")

# %%
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
data.loc[(data['Country']=='Brazil')&(data['Gender']=='Female')&(data['Department']=='IT'),:]
# Out:
#        EEID         Full Name                       Job Title Department  \
# 39   E01417         Leah Pena            Enterprise Architect         IT
# 60   E00699         Ava Ayala                      Sr. Manger         IT
# 87   E03440   Genesis Navarro  Cloud Infrastructure Architect         IT
# 88   E00431   Eliza Hernandez               Network Architect         IT
# 97   E04931        Zoe Romero               Network Architect         IT
# 269  E01525    Charlotte Ruiz        Computer Systems Manager         IT
# 386  E01241   Hadley Guerrero                      Sr. Manger         IT
# 624  E01432      Peyton Garza                 Systems Analyst         IT
# 705  E02192        Lucy Avila             Solutions Architect         IT
# 731  E01649      Eva Alvarado        Computer Systems Manager         IT
# 825  E00035  Lillian Gonzales  Cloud Infrastructure Architect         IT
# 886  E00102       Riley Rojas               Network Architect         IT
#
# ...

# %%
data.loc[[0,1,2,3,4] ,: ]
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# ...
