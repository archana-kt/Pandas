# %% [markdown]
# # Pandas DataFrame at iat

# %% [raw]
# # Now we need to access a single value for row column pair by integer position or by position accessing the single value for the column.

# %%
# Both row and column we are accessing single value

# %%
import pandas as pd

# %% [markdown]
# # pandas.DataFrame.at

# %%
# Both row and column we are accessing single value using this method

# %%
data = pd.read_csv("C:/Users/91701/Desktop/Dataset/worldcities2.csv", encoding='latin-1')

# %%
data
# Out:
#                 city     city_ascii              city_alt      lat     lng  \
# 0        Saint-Oblas    Saint-Oblas                   NaN  45.5674  5.0447
# 1           Louresse       Louresse  Louresse-Rochemenier  47.2394 -0.3136
# 2              Olmet          Olmet                   NaN  45.7100  3.6614
# 3              Olmet          Olmet                   NaN  44.9542  2.6108
# 4        Gottenhouse    Gottenhouse                   NaN  48.7208  7.3611
# ...              ...            ...                   ...      ...     ...
# 59059    La Rochette    La Rochette              Rochette  45.2609  6.2881
# 59060    La Rochette    La Rochette                   NaN  45.3056  3.4747
# 59061  Saint-Eutrope  Saint-Eutrope                   NaN  45.4181  0.1114
# 59062  Saint-Eutrope  Saint-Eutrope                   NaN  44.4535  0.5204
# 59063        Taillis        Taillis                   NaN  48.1889 -1.2389
#
# ...

# %% [raw]
# data.at?

# %% [raw]
# Access a single value for a row/column label pair.
#
# Similar to ``loc``, in that both provide label-based lookups. Use
# ``at`` if you only need to get or set a single value in a DataFrame
# or Series.
#
# Raises
# ------
# KeyError
#     * If getting a value and 'label' does not exist in a DataFrame or
#         Series.
# ValueError
#     * If row/column label pair is not a tuple or if any label from
#         the pair is not a scalar for DataFrame.
#     * If label is list-like (*excluding* NamedTuple) for Series.
#
# See Also
# --------
# DataFrame.at : Access a single value for a row/column pair by label.
# DataFrame.iat : Access a single value for a row/column pair by integer
#     position.
# DataFrame.loc : Access a group of rows and columns by label(s).
# DataFrame.iloc : Access a group of rows and columns by integer
#     position(s).
# Series.at : Access a single value by label.
# Series.iat : Access a single value by integer position.
# Notes
# -----
# See :ref:`Fast scalar value getting and setting <indexing.basics.get_value>`
# for more details.
#
# Examples
# --------
# >>> df = pd.DataFrame([[0, 2, 3], [0, 4, 1], [10, 20, 30]],
# ...                   index=[4, 5, 6], columns=['A', 'B', 'C'])
# >>> df
#     A   B   C
# 4   0   2   3
# 5   0   4   1
# 6  10  20  30
#
# Get value at specified row/column pair
#
# >>> df.at[4, 'B']
# 2
#
# Set value at specified row/column pair
#
# >>> df.at[4, 'B'] = 10
# >>> df.at[4, 'B']
# 10
#
# Get value within a Series
#
# >>> df.loc[5].at['B']
# 4

# %%
df = pd.DataFrame([[0, 2, 3], [0, 4, 1], [10, 20, 30]], index=[4, 5, 6], columns=['A', 'B', 'C'])

# %%
df
# Out:
#     A   B   C
# 4   0   2   3
# 5   0   4   1
# 6  10  20  30

# %%
# Get value at specified row/column pair

# %%
df.at[4,'B']
# Out:
# 2

# %%
df.at[6,'C']
# Out:
# 30

# %%
# Get value within a Series

# %%
df.loc[5]
# Out:
# A    0
# B    4
# C    1
# Name: 5, dtype: int64

# %%
df.loc[6]
# Out:
# A    10
# B    20
# C    30
# Name: 6, dtype: int64

# %%
df.loc[6].at['B']
# Out:
# 20

# %%
data
# Out:
#                 city     city_ascii              city_alt      lat     lng  \
# 0        Saint-Oblas    Saint-Oblas                   NaN  45.5674  5.0447
# 1           Louresse       Louresse  Louresse-Rochemenier  47.2394 -0.3136
# 2              Olmet          Olmet                   NaN  45.7100  3.6614
# 3              Olmet          Olmet                   NaN  44.9542  2.6108
# 4        Gottenhouse    Gottenhouse                   NaN  48.7208  7.3611
# ...              ...            ...                   ...      ...     ...
# 59059    La Rochette    La Rochette              Rochette  45.2609  6.2881
# 59060    La Rochette    La Rochette                   NaN  45.3056  3.4747
# 59061  Saint-Eutrope  Saint-Eutrope                   NaN  45.4181  0.1114
# 59062  Saint-Eutrope  Saint-Eutrope                   NaN  44.4535  0.5204
# 59063        Taillis        Taillis                   NaN  48.1889 -1.2389
#
# ...

# %%
data.head()
# Out:
#           city   city_ascii              city_alt      lat     lng country  \
# 0  Saint-Oblas  Saint-Oblas                   NaN  45.5674  5.0447  France
# 1     Louresse     Louresse  Louresse-Rochemenier  47.2394 -0.3136  France
# 2        Olmet        Olmet                   NaN  45.7100  3.6614  France
# 3        Olmet        Olmet                   NaN  44.9542  2.6108  France
# 4  Gottenhouse  Gottenhouse                   NaN  48.7208  7.3611  France
#
#   iso2 iso3             admin_name      admin_name_ascii admin_code  \
# 0   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 1   FR  FRA       Pays de la Loire      Pays de la Loire       FR-R
# 2   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 3   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 4   FR  FRA              Grand Est             Grand Est     FR-GES
#
#   admin_type capital  density  population  population_proper  ranking  \
# ...

# %%
data.at[0,'city_ascii']
# Out:
# 'Saint-Oblas'

# %%
data.at[3,'lng']
# Out:
# 2.6108

# %%
# to assign the value mutate

# %%
data.at[2, 'city'] = 'Delhi'

# %%
data.head()
# Out:
#           city   city_ascii              city_alt      lat     lng country  \
# 0  Saint-Oblas  Saint-Oblas                   NaN  45.5674  5.0447  France
# 1     Louresse     Louresse  Louresse-Rochemenier  47.2394 -0.3136  France
# 2        Delhi        Olmet                   NaN  45.7100  3.6614  France
# 3        Olmet        Olmet                   NaN  44.9542  2.6108  France
# 4  Gottenhouse  Gottenhouse                   NaN  48.7208  7.3611  France
#
#   iso2 iso3             admin_name      admin_name_ascii admin_code  \
# 0   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 1   FR  FRA       Pays de la Loire      Pays de la Loire       FR-R
# 2   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 3   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 4   FR  FRA              Grand Est             Grand Est     FR-GES
#
#   admin_type capital  density  population  population_proper  ranking  \
# ...

# %% [markdown]
# # Another method

# %% [markdown]
# # iat

# %%
# Access a single value for a row/column by integer position

# %%
data.iat[2,'city']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 data.iat[2,'city']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2381, in _ScalarAccessIndexer.__getitem__(self, key)
#    2378     else:
#    2379         raise ValueError("Invalid call for scalar access (getting)!")
# -> 2381 key = self._convert_key(key)
#    2382 return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2455, in _iAtIndexer._convert_key(self, key)
#    2453 for i in key:
#    2454     if not is_integer(i):
# -> 2455         raise ValueError("iAt based indexing can only have integer indexers")
#    2456 return key
#
# ValueError: iAt based indexing can only have integer indexers

# %%
# See this shows error, bcoz it accepts only integer for indexing

# %%
data.head()
# Out:
#           city   city_ascii              city_alt      lat     lng country  \
# 0  Saint-Oblas  Saint-Oblas                   NaN  45.5674  5.0447  France
# 1     Louresse     Louresse  Louresse-Rochemenier  47.2394 -0.3136  France
# 2        Delhi        Olmet                   NaN  45.7100  3.6614  France
# 3        Olmet        Olmet                   NaN  44.9542  2.6108  France
# 4  Gottenhouse  Gottenhouse                   NaN  48.7208  7.3611  France
#
#   iso2 iso3             admin_name      admin_name_ascii admin_code  \
# 0   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 1   FR  FRA       Pays de la Loire      Pays de la Loire       FR-R
# 2   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 3   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 4   FR  FRA              Grand Est             Grand Est     FR-GES
#
#   admin_type capital  density  population  population_proper  ranking  \
# ...

# %%
data.iat[0,0]
# Out:
# 'Saint-Oblas'

# %%
data.iat[0,3]
# Out:
# 45.5674

# %%
# which means it takes all the columns as 0,1,2... 'city'=> 0, 'city_ascii' => 1, and so on

# %%
data.columns
# Out:
# Index(['city', 'city_ascii', 'city_alt', 'lat', 'lng', 'country', 'iso2',
#        'iso3', 'admin_name', 'admin_name_ascii', 'admin_code', 'admin_type',
#        'capital', 'density', 'population', 'population_proper', 'ranking',
#        'timezone', 'same_name', 'id'],
#       dtype='object')

# %%
data.iat[2,0] = 'New Delhi'

# %%
data.head()
# Out:
#           city   city_ascii              city_alt      lat     lng country  \
# 0  Saint-Oblas  Saint-Oblas                   NaN  45.5674  5.0447  France
# 1     Louresse     Louresse  Louresse-Rochemenier  47.2394 -0.3136  France
# 2    New Delhi        Olmet                   NaN  45.7100  3.6614  France
# 3        Olmet        Olmet                   NaN  44.9542  2.6108  France
# 4  Gottenhouse  Gottenhouse                   NaN  48.7208  7.3611  France
#
#   iso2 iso3             admin_name      admin_name_ascii admin_code  \
# 0   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 1   FR  FRA       Pays de la Loire      Pays de la Loire       FR-R
# 2   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 3   FR  FRA  Auvergne-Rh̫ne-Alpes  Auvergne-Rhone-Alpes     FR-ARA
# 4   FR  FRA              Grand Est             Grand Est     FR-GES
#
#   admin_type capital  density  population  population_proper  ranking  \
# ...
