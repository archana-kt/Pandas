# %% [markdown]
# ![WhatsApp%20Image%202023-11-24%20at%2012.30.47%20PM.jpeg](attachment:WhatsApp%20Image%202023-11-24%20at%2012.30.47%20PM.jpeg)

# %% [markdown]
# # Qualitative or Categorical

# %% [raw]
# The Quantitative data are further classified into two parts :
#     -> Nominal
#     -> Ordinal

# %% [markdown]
# ## Nominal Data

# %% [raw]
# Nominal Data is used to label variables without any order or quantitative value.

# %% [raw]
# Examples of Nominal Data :
#
# Colour of hair (Blonde, red, Brown, Black, etc.)
# Marital status (Single, Widowed, Married)
# Nationality (Indian, German, American)
# Gender (Male, Female, Others)
# Eye Color (Black, Brown, etc.)

# %% [markdown]
# ## Ordinal

# %% [raw]
# The ordinal data only shows the sequences and cannot use for statistical analysis.

# %% [raw]
# These data are used for observation like customer satisfaction, happiness, etc., but we can’t do any arithmetical tasks on them.

# %% [raw]
# Examples:
#     When companies ask for feedback, experience, or satisfaction on a scale of 1 to 10
#     Letter grades in the exam (A, B, C, D, etc.)

# %% [markdown]
# # Nominal data cannot be used to compare with one another
#
# # Ordinal data can help to compare one item with another by ranking or ordering

# %% [markdown]
# # Quantitative Data

# %% [raw]
# Quantitative data can be expressed in numerical values, making it countable and including statistical data analysis.

# %% [raw]
# Examples of Quantitative Data :
# Height or weight of a person or object
# Room Temperature

# %% [raw]
# The Quantitative data are further classified into two parts :

# %% [markdown]
# ## Discrete Data

# %% [raw]
# The term discrete means distinct or separate. The discrete data contain the values that fall under integers or whole numbers.

# %% [raw]
# Discrete variables have values that are counted.

# %% [raw]
# Examples of Discrete Data :
# Total numbers of students present in a class
# Cost of a cell phone

# %%
# Mainly for counting we go for discrete and also whole number

# %% [markdown]
# ## Continuous Data

# %% [raw]
# Continuous data are in the form of fractional numbers. It can be the version of an android phone, the height of a person, the length of an object, etc.

# %% [raw]
# A continuous variable takes on an infinite number of possible values within a given range.

# %% [raw]
# Continuous data has the following main characteristics:
#
# The data is collected for one or more continuous random variables
#
# The observations in your data could take on an infinite number of possible values within a range
#
# The data are measured rather than counted

# %% [raw]
# Examples of Continuous Data :
# Height of a person
# Speed of a vehicle

# %%
# Mainly for decimal or fractional numbers and also it has ranges

# %% [markdown]
# ## Interval

# %% [raw]
# Interval data is fun (and useful) because it's concerned with both the order and difference between your variables. This allows you to measure standard deviation and central tendency.

# %% [raw]
# Eg: temperatures in degrees celsius

# %% [markdown]
# ## Ratio data

# %% [raw]
# Ratio data tells us about the order of variables, the differences between them, and they have that absolute zero.

# %% [raw]
# For instance, height is ratio data. It is not possible to have negative height. If an object's height is zero, then there is no object. This is different than something like temperature. Both 0 degrees and -5 degrees are completely valid and meaningful temperatures.

# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/archanaqueen/Desktop/employees.csv", encoding='latin-1')

# %%
data
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
data.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
data['First Name']
# Out:
# 0      Douglas
# 1       Thomas
# 2        Maria
# 3        Jerry
# 4        Larry
#         ...
# 995      Henry
# 996    Phillip
# 997    Russell
# 998      Larry
# 999     Albert
# Name: First Name, Length: 1000, dtype: object

# %%
type(data['First Name'])
# Out:
# pandas.core.series.Series

# %%
# It is a qualitative -> nominal data (bcoz there is no ranking)

# %%
data['Gender']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
sns.histplot(data['Gender'])
plt.show()

# %%
# It is a qualitative -> nominal data (bcoz there is no ranking)

# %%
data['Start Date']
# Out:
# 0        8/6/1993
# 1       3/31/1996
# 2       4/23/1993
# 3        3/4/2005
# 4       1/24/1998
#           ...
# 995    11/23/2014
# 996     1/31/1984
# 997     5/20/2013
# 998     4/20/2013
# 999     5/15/2012
# Name: Start Date, Length: 1000, dtype: object

# %%
# It is a numerical value and time-series data

# %%
data['Last Login Time']
# Out:
# 0      12:42 PM
# 1       6:53 AM
# 2      11:17 AM
# 3       1:00 PM
# 4       4:47 PM
#          ...
# 995     6:09 AM
# 996     6:30 AM
# 997    12:39 PM
# 998     4:45 PM
# 999     6:24 PM
# Name: Last Login Time, Length: 1000, dtype: object

# %%
# It is a numerical value and time-series data

# %%
data['Salary']
# Out:
# 0       97308
# 1       61933
# 2      130590
# 3      138705
# 4      101004
#         ...
# 995    132483
# 996     42392
# 997     96914
# 998     60500
# 999    129949
# Name: Salary, Length: 1000, dtype: int64

# %%
# It is a quantitative -> discrete (bcoz there is no range and also no decimal values)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.histplot(data['Salary'])
plt.show()

# %%
data['Bonus %']
# Out:
# 0       6.945
# 1       4.170
# 2      11.858
# 3       9.340
# 4       1.389
#         ...
# 995    16.655
# 996    19.675
# 997     1.421
# 998    11.985
# 999    10.169
# Name: Bonus %, Length: 1000, dtype: float64

# %%
sns.histplot(data['Bonus %'])
plt.show()

# %%
# It is a quantitative -> continuous (decimal values)

# %%
data['Senior Management']
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Senior Management, Length: 1000, dtype: object

# %%
data['Team']
# Out:
# 0                 Marketing
# 1                       NaN
# 2                   Finance
# 3                   Finance
# 4           Client Services
#                ...
# 995            Distribution
# 996                 Finance
# 997                 Product
# 998    Business Development
# 999                   Sales
# Name: Team, Length: 1000, dtype: object

# %%
# It is a qualitative -> nominal data

# %% [markdown]
# # Question may ask from this dataset

# %%
data
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
# How many male employees are working in this company?

# %% [raw]
# It is numerical or quantitave -> discrete data(bcoz countable)

# %%
data['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
data[data['Gender'] == 'Male']
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas   Male  3/31/1996         6:53 AM   61933    4.170
# 3        Jerry   Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry   Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis   Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip   Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
data[data['Gender'] == 'Male'].index
# Out:
# Int64Index([  0,   1,   3,   4,   5,  12,  13,  16,  17,  21,
#             ...
#             978, 979, 981, 983, 992, 994, 996, 997, 998, 999],
#            dtype='int64', length=424)

# %%
len(data[data['Gender'] == 'Male'])
# Out:
# 424
