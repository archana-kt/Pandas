# %% [markdown]
# # Pandas DataFrame read excel with cleaning

# %%
import pandas as pd

# %%
data = pd.ExcelFile("/Users/archanaqueen/Desktop/i18n/Daily Class/Pandas/Dataset_work/Cola.xlsx")

# %%
data

# %%
data.parse()
# Out:
#      Data provided by SimFin  \
# 0                        NaN
# 1    Profit & Loss statement
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 98                       NaN
# 99                       NaN
# 100                      NaN
# 101                      NaN
# 102                      NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                       in million USD     FY '09     FY '10
# 3                               NET OPERATING REVENUES      30990      35119
# 4                                   Cost of goods sold      11088      12693
# ..                                                 ...        ...        ...
# ...

# %%
data.sheet_names
# Out:
# ['COCA COLA CO']

# %%
# Here there is only one sheet. so no problem. If there is no details in sheet1 means, we will get empty dataframe

# %%
# To avoid that, we need to give parse(sheet_name)

# %%
data.parse("COCA COLA CO")
# Out:
#      Data provided by SimFin  \
# 0                        NaN
# 1    Profit & Loss statement
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 98                       NaN
# 99                       NaN
# 100                      NaN
# 101                      NaN
# 102                      NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                       in million USD     FY '09     FY '10
# 3                               NET OPERATING REVENUES      30990      35119
# 4                                   Cost of goods sold      11088      12693
# ..                                                 ...        ...        ...
# ...

# %%
# To avoid these process, we can directly use, read_excel

# %%
data = pd.read_excel("/Users/archanaqueen/Desktop/i18n/Daily Class/Pandas/Dataset_work/Cola.xlsx",sheet_name="COCA COLA CO")

# %%
data
# Out:
#      Data provided by SimFin  \
# 0                        NaN
# 1    Profit & Loss statement
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 98                       NaN
# 99                       NaN
# 100                      NaN
# 101                      NaN
# 102                      NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                       in million USD     FY '09     FY '10
# 3                               NET OPERATING REVENUES      30990      35119
# 4                                   Cost of goods sold      11088      12693
# ..                                                 ...        ...        ...
# ...

# %%
data = pd.read_excel("/Users/archanaqueen/Desktop/i18n/Daily Class/Pandas/Dataset_work/Cola.xlsx",sheet_name="COCA COLA CO", header=5)

# %%
data
# Out:
#    Unnamed: 0                                 Cost of goods sold  11088  \
# 0         NaN                                       Gross Profit  19902
# 1         NaN       Selling, general and administrative expenses  11358
# 2         NaN                            Other operating charges    313
# 3         NaN                                   Operating Income   8231
# 4         NaN                                    Interest income    249
# ..        ...                                                ...    ...
# 93        NaN  Effect of exchange rate changes on cash and ca...    576
# 94        NaN  Cash Provided by (Used in) Investing Activitie...    NaN
# 95        NaN  Cash Provided by (Used in) Financing Activitie...    NaN
# 96        NaN  Net Cash Provided by (Used in) Discontinued Op...    NaN
# 97        NaN            Net increase (decrease) during the year   2320
#
#     12693  18215  19053  18421  17889  17482  16465  13255  11770
# ...

# %%
# if header starts from 5 means

# %%
data.head()
# Out:
#   Unnamed: 0                            Cost of goods sold  11088  12693  \
# 0        NaN                                  Gross Profit  19902  22426
# 1        NaN  Selling, general and administrative expenses  11358  13194
# 2        NaN                       Other operating charges    313    819
# 3        NaN                              Operating Income   8231   8413
# 4        NaN                               Interest income    249    317
#
#    18215  19053  18421  17889  17482  16465  13255  11770
# 0  28327  28964  28433  28109  26812  25398  22155  20086
# 1  17422  17738  17310  17218  16427  15262  12654  10307
# 2    732    447    895   1183   1657   1510   1902   1079
# 3  10173  10779  10228   9708   8728   8626   7599   8700
# 4    483    471    534    594    613    642    677    682

# %%
# Here we can see that, the 1st column is considered as Unnamed

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          2 non-null      object
#  1   Cost of goods sold  94 non-null     object
#  2   11088               79 non-null     object
#  3   12693               79 non-null     object
#  4   18215               79 non-null     object
#  5   19053               79 non-null     object
#  6   18421               79 non-null     object
#  7   17889               79 non-null     object
#  8   17482               87 non-null     object
#  9   16465               89 non-null     object
#  10  13255               90 non-null     object
#  11  11770               90 non-null     object
# dtypes: object(12)
# memory usage: 9.3+ KB

# %%
# So we are going to use => usecols attribute to avoid the unwanted columns or unwanted spaced columns

# %%
data = pd.read_excel("/Users/archanaqueen/Desktop/i18n/Daily Class/Pandas/Dataset_work/Cola.xlsx",sheet_name="COCA COLA CO",usecols="B:L")

# %%
data
# Out:
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                       in million USD     FY '09     FY '10
# 3                               NET OPERATING REVENUES      30990      35119
# 4                                   Cost of goods sold      11088      12693
# ..                                                 ...        ...        ...
# 98   Effect of exchange rate changes on cash and ca...        576       -166
# 99   Cash Provided by (Used in) Investing Activitie...        NaN        NaN
# 100  Cash Provided by (Used in) Financing Activitie...        NaN        NaN
# 101  Net Cash Provided by (Used in) Discontinued Op...        NaN        NaN
# 102            Net increase (decrease) during the year       2320       1496
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 1   97 non-null     object
#  1   Unnamed: 2   82 non-null     object
#  2   Unnamed: 3   82 non-null     object
#  3   Unnamed: 4   82 non-null     object
#  4   Unnamed: 5   82 non-null     object
#  5   Unnamed: 6   82 non-null     object
#  6   Unnamed: 7   82 non-null     object
#  7   Unnamed: 8   90 non-null     object
#  8   Unnamed: 9   92 non-null     object
#  9   Unnamed: 10  93 non-null     object
#  10  Unnamed: 11  93 non-null     object
# dtypes: object(11)
# memory usage: 9.0+ KB

# %%
# See the unnamed column is now avoided

# %%
# To avoid the inbetween nan columns, we can use slicing method

# %%
data = pd.read_excel("/Users/archanaqueen/Desktop/i18n/Daily Class/Pandas/Dataset_work/Cola.xlsx",sheet_name="COCA COLA CO",usecols="B:E,I:L")

# %%
data
# Out:
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                       in million USD     FY '09     FY '10
# 3                               NET OPERATING REVENUES      30990      35119
# 4                                   Cost of goods sold      11088      12693
# ..                                                 ...        ...        ...
# 98   Effect of exchange rate changes on cash and ca...        576       -166
# 99   Cash Provided by (Used in) Investing Activitie...        NaN        NaN
# 100  Cash Provided by (Used in) Financing Activitie...        NaN        NaN
# 101  Net Cash Provided by (Used in) Discontinued Op...        NaN        NaN
# 102            Net increase (decrease) during the year       2320       1496
#
# ...

# %%
# Now we have 8 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 1   97 non-null     object
#  1   Unnamed: 2   82 non-null     object
#  2   Unnamed: 3   82 non-null     object
#  3   Unnamed: 4   82 non-null     object
#  4   Unnamed: 8   90 non-null     object
#  5   Unnamed: 9   92 non-null     object
#  6   Unnamed: 10  93 non-null     object
#  7   Unnamed: 11  93 non-null     object
# dtypes: object(8)
# memory usage: 6.6+ KB

# %%
data.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
# To get the "Yes" or "No" values, we can use true_values attribute

# %%
data = pd.read_excel("/Users/archanaqueen/Desktop/i18n/Daily Class/Pandas/Dataset_work/Cola.xlsx",sheet_name="COCA COLA CO",usecols="B:E,I:L", true_values=["Yes"])

# %%
data
# Out:
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                       in million USD     FY '09     FY '10
# 3                               NET OPERATING REVENUES      30990      35119
# 4                                   Cost of goods sold      11088      12693
# ..                                                 ...        ...        ...
# 98   Effect of exchange rate changes on cash and ca...        576       -166
# 99   Cash Provided by (Used in) Investing Activitie...        NaN        NaN
# 100  Cash Provided by (Used in) Financing Activitie...        NaN        NaN
# 101  Net Cash Provided by (Used in) Discontinued Op...        NaN        NaN
# 102            Net increase (decrease) during the year       2320       1496
#
# ...

# %%
data.dtypes
# Out:
# Unnamed: 1     object
# Unnamed: 2     object
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 8     object
# Unnamed: 9     object
# Unnamed: 10    object
# Unnamed: 11    object
# dtype: object

# %%
# But here my dataset there is no yes or no. If we have it, we can change to boolean values

# %%
data.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
data["Unnamed: 1"]
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                         in million USD
# 3                                 NET OPERATING REVENUES
# 4                                     Cost of goods sold
#                              ...
# 98     Effect of exchange rate changes on cash and ca...
# 99     Cash Provided by (Used in) Investing Activitie...
# 100    Cash Provided by (Used in) Financing Activitie...
# 101    Net Cash Provided by (Used in) Discontinued Op...
# 102              Net increase (decrease) during the year
# Name: Unnamed: 1, Length: 103, dtype: object

# %%
type(data["Unnamed: 1"])
# Out:
# pandas.core.series.Series

# %%
type(data["Unnamed: 10"][0])
# Out:
# float
