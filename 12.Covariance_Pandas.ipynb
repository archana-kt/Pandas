# %% [markdown]
# # Co-variance

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# data = ![image.png](attachment:image.png)

# %%
data = pd.DataFrame({
    "a":[1,2,3,4,5],
    "b":[6,7,8,9,10]
})

# %%
data
# Out:
#    a   b
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
# Calculate covariance using Pandas
covariance_pandas = data["a"].cov(data["b"])

# %%
covariance_pandas
# Out:
# 2.5

# %%
# Manual calculation

# %%
# To find mean

# %%
mean_a = np.mean(data["a"])

# %%
mean_a
# Out:
# 3.0

# %%
mean_a = np.sum(data["a"]) / len(data["a"])

# %%
mean_a
# Out:
# 3.0

# %%
data["a_bar"] = mean_a

# %%
data
# Out:
#    a   b  a_bar
# 0  1   6    3.0
# 1  2   7    3.0
# 2  3   8    3.0
# 3  4   9    3.0
# 4  5  10    3.0

# %%
mean_b = np.sum(data["b"]) / len(data["b"])

# %%
mean_b
# Out:
# 8.0

# %%
mean_b = np.mean(data["b"])

# %%
mean_b
# Out:
# 8.0

# %%
data["b_bar"] = mean_b

# %%
data
# Out:
#    a   b  a_bar  b_bar
# 0  1   6    3.0    8.0
# 1  2   7    3.0    8.0
# 2  3   8    3.0    8.0
# 3  4   9    3.0    8.0
# 4  5  10    3.0    8.0

# %%
data["a-a_bar"] = data["a"] - data["a_bar"]

# %%
data
# Out:
#    a   b  a_bar  b_bar  a-a_bar
# 0  1   6    3.0    8.0     -2.0
# 1  2   7    3.0    8.0     -1.0
# 2  3   8    3.0    8.0      0.0
# 3  4   9    3.0    8.0      1.0
# 4  5  10    3.0    8.0      2.0

# %%
data["b-b_bar"] = data["b"] - data["b_bar"]

# %%
data["b-b_bar"]
# Out:
# 0   -2.0
# 1   -1.0
# 2    0.0
# 3    1.0
# 4    2.0
# Name: b-b_bar, dtype: float64

# %%
data
# Out:
#    a   b  a_bar  b_bar  a-a_bar  b-b_bar
# 0  1   6    3.0    8.0     -2.0     -2.0
# 1  2   7    3.0    8.0     -1.0     -1.0
# 2  3   8    3.0    8.0      0.0      0.0
# 3  4   9    3.0    8.0      1.0      1.0
# 4  5  10    3.0    8.0      2.0      2.0

# %%
res = np.multiply(data["a-a_bar"],data["b-b_bar"])

# %%
res
# Out:
# 0    4.0
# 1    1.0
# 2    0.0
# 3    1.0
# 4    4.0
# dtype: float64

# %%
data["a-a_bar","b-b_bar"] = res

# %%
data["prod"] = data["a-a_bar","b-b_bar"]

# %%
data
# Out:
#    a   b  a_bar  b_bar  a-a_bar  b-b_bar  (a-a_bar, b-b_bar)  prod
# 0  1   6    3.0    8.0     -2.0     -2.0                 4.0   4.0
# 1  2   7    3.0    8.0     -1.0     -1.0                 1.0   1.0
# 2  3   8    3.0    8.0      0.0      0.0                 0.0   0.0
# 3  4   9    3.0    8.0      1.0      1.0                 1.0   1.0
# 4  5  10    3.0    8.0      2.0      2.0                 4.0   4.0

# %%
var = sum(data['prod'])/(len(data['a'])-1)

# %%
var
# Out:
# 2.5

# %%
np.cov(data["a"],data["b"])
# Out:
# array([[2.5, 2.5],
#        [2.5, 2.5]])
