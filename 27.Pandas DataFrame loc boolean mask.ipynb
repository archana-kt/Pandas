# %% [markdown]
# # Pandas DataFrame loc boolean mask

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/91701/Desktop/Dataset/worldcities2.csv", encoding='latin-1')

# %%
data
# Out:
#                 city     city_ascii              city_alt      lat     lng  \
# 0        Saint-Oblas    Saint-Oblas                   NaN  45.5674  5.0447
# 1           Louresse       Louresse  Louresse-Rochemenier  47.2394 -0.3136
# 2              Olmet          Olmet                   NaN  45.7100  3.6614
# 3              Olmet          Olmet                   NaN  44.9542  2.6108
# 4        Gottenhouse    Gottenhouse                   NaN  48.7208  7.3611
# ...              ...            ...                   ...      ...     ...
# 59059    La Rochette    La Rochette              Rochette  45.2609  6.2881
# 59060    La Rochette    La Rochette                   NaN  45.3056  3.4747
# 59061  Saint-Eutrope  Saint-Eutrope                   NaN  45.4181  0.1114
# 59062  Saint-Eutrope  Saint-Eutrope                   NaN  44.4535  0.5204
# 59063        Taillis        Taillis                   NaN  48.1889 -1.2389
#
# ...

# %%
data.columns
# Out:
# Index(['city', 'city_ascii', 'city_alt', 'lat', 'lng', 'country', 'iso2',
#        'iso3', 'admin_name', 'admin_name_ascii', 'admin_code', 'admin_type',
#        'capital', 'density', 'population', 'population_proper', 'ranking',
#        'timezone', 'same_name', 'id'],
#       dtype='object')

# %%
data.loc[0:5,['city']]
# Out:
#           city
# 0  Saint-Oblas
# 1     Louresse
# 2        Olmet
# 3        Olmet
# 4  Gottenhouse
# 5      Bergues

# %%
data.loc[0:5,['city','population']]
# Out:
#           city  population
# 0  Saint-Oblas         NaN
# 1     Louresse       872.0
# 2        Olmet       161.0
# 3        Olmet         NaN
# 4  Gottenhouse       382.0
# 5      Bergues      3637.0

# %% [markdown]
# # Another method

# %%
data.loc[0:5,'city':'country']
# Out:
#           city   city_ascii              city_alt      lat     lng country
# 0  Saint-Oblas  Saint-Oblas                   NaN  45.5674  5.0447  France
# 1     Louresse     Louresse  Louresse-Rochemenier  47.2394 -0.3136  France
# 2        Olmet        Olmet                   NaN  45.7100  3.6614  France
# 3        Olmet        Olmet                   NaN  44.9542  2.6108  France
# 4  Gottenhouse  Gottenhouse                   NaN  48.7208  7.3611  France
# 5      Bergues      Bergues                   NaN  50.9686  2.4342  France

# %% [markdown]
# # Boolean Mask

# %%
data
# Out:
#                 city     city_ascii              city_alt      lat     lng  \
# 0        Saint-Oblas    Saint-Oblas                   NaN  45.5674  5.0447
# 1           Louresse       Louresse  Louresse-Rochemenier  47.2394 -0.3136
# 2              Olmet          Olmet                   NaN  45.7100  3.6614
# 3              Olmet          Olmet                   NaN  44.9542  2.6108
# 4        Gottenhouse    Gottenhouse                   NaN  48.7208  7.3611
# ...              ...            ...                   ...      ...     ...
# 59059    La Rochette    La Rochette              Rochette  45.2609  6.2881
# 59060    La Rochette    La Rochette                   NaN  45.3056  3.4747
# 59061  Saint-Eutrope  Saint-Eutrope                   NaN  45.4181  0.1114
# 59062  Saint-Eutrope  Saint-Eutrope                   NaN  44.4535  0.5204
# 59063        Taillis        Taillis                   NaN  48.1889 -1.2389
#
# ...

# %%
data.country
# Out:
# 0        France
# 1        France
# 2        France
# 3        France
# 4        France
#           ...
# 59059    France
# 59060    France
# 59061    France
# 59062    France
# 59063    France
# Name: country, Length: 59064, dtype: object

# %%
data['country']
# Out:
# 0        France
# 1        France
# 2        France
# 3        France
# 4        France
#           ...
# 59059    France
# 59060    France
# 59061    France
# 59062    France
# 59063    France
# Name: country, Length: 59064, dtype: object

# %%
data['ranking']
# Out:
# 0        4
# 1        3
# 2        3
# 3        4
# 4        3
#         ..
# 59059    4
# 59060    4
# 59061    3
# 59062    4
# 59063    3
# Name: ranking, Length: 59064, dtype: int64

# %%
data['ranking'].unique()
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
len(data['ranking'].unique())
# Out:
# 5

# %%
data['ranking'] == 3
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 59059    False
# 59060    False
# 59061     True
# 59062    False
# 59063     True
# Name: ranking, Length: 59064, dtype: bool

# %%
data[data['ranking'] == 3] # when i need only ranking=3 values which is true
# Out:
#                            city              city_ascii  \
# 1                      Louresse                Louresse
# 2                         Olmet                   Olmet
# 4                   Gottenhouse             Gottenhouse
# 7      Saint-Martin-dâArrossa  Saint-Martin-d'Arrossa
# 8                         Marre                   Marre
# ...                         ...                     ...
# 59056       Cognocoli-Monticchi     Cognocoli-Monticchi
# 59057               La Rochette             La Rochette
# 59058               La Rochette             La Rochette
# 59061             Saint-Eutrope           Saint-Eutrope
# 59063                   Taillis                 Taillis
#
#                                    city_alt      lat     lng country iso2  \
# 1                      Louresse-Rochemenier  47.2394 -0.3136  France   FR
# 2                                       NaN  45.7100  3.6614  France   FR
# ...

# %%
data.loc[data['ranking'] == 3]
# Out:
#                            city              city_ascii  \
# 1                      Louresse                Louresse
# 2                         Olmet                   Olmet
# 4                   Gottenhouse             Gottenhouse
# 7      Saint-Martin-dâArrossa  Saint-Martin-d'Arrossa
# 8                         Marre                   Marre
# ...                         ...                     ...
# 59056       Cognocoli-Monticchi     Cognocoli-Monticchi
# 59057               La Rochette             La Rochette
# 59058               La Rochette             La Rochette
# 59061             Saint-Eutrope           Saint-Eutrope
# 59063                   Taillis                 Taillis
#
#                                    city_alt      lat     lng country iso2  \
# 1                      Louresse-Rochemenier  47.2394 -0.3136  France   FR
# 2                                       NaN  45.7100  3.6614  France   FR
# ...

# %% [markdown]
# # Both are same and this is called Boolean Mask

# %% [raw]
# Bcoz we created Boolean array first and then pass it on the loc.

# %%
data.loc[data['lat'] > 30]
# Out:
#                 city     city_ascii              city_alt      lat     lng  \
# 0        Saint-Oblas    Saint-Oblas                   NaN  45.5674  5.0447
# 1           Louresse       Louresse  Louresse-Rochemenier  47.2394 -0.3136
# 2              Olmet          Olmet                   NaN  45.7100  3.6614
# 3              Olmet          Olmet                   NaN  44.9542  2.6108
# 4        Gottenhouse    Gottenhouse                   NaN  48.7208  7.3611
# ...              ...            ...                   ...      ...     ...
# 59059    La Rochette    La Rochette              Rochette  45.2609  6.2881
# 59060    La Rochette    La Rochette                   NaN  45.3056  3.4747
# 59061  Saint-Eutrope  Saint-Eutrope                   NaN  45.4181  0.1114
# 59062  Saint-Eutrope  Saint-Eutrope                   NaN  44.4535  0.5204
# 59063        Taillis        Taillis                   NaN  48.1889 -1.2389
#
# ...

# %%
# This is also called Boolean Mask

# %%
# When i need latitude above 45 and below 49

# %%
data.loc[(data['lat'] > 45) & (data['lat'] < 49)]
# Out:
#                 city     city_ascii              city_alt      lat     lng  \
# 0        Saint-Oblas    Saint-Oblas                   NaN  45.5674  5.0447
# 1           Louresse       Louresse  Louresse-Rochemenier  47.2394 -0.3136
# 2              Olmet          Olmet                   NaN  45.7100  3.6614
# 4        Gottenhouse    Gottenhouse                   NaN  48.7208  7.3611
# 6        Villelongue    Villelongue                   NaN  45.8647  2.8817
# ...              ...            ...                   ...      ...     ...
# 59057    La Rochette    La Rochette                   NaN  45.4586  6.1203
# 59059    La Rochette    La Rochette              Rochette  45.2609  6.2881
# 59060    La Rochette    La Rochette                   NaN  45.3056  3.4747
# 59061  Saint-Eutrope  Saint-Eutrope                   NaN  45.4181  0.1114
# 59063        Taillis        Taillis                   NaN  48.1889 -1.2389
#
# ...

# %%
data.loc[data['city'].str.contains('T')] # T starting cities are displayed
# Out:
#                     city         city_ascii city_alt      lat     lng country  \
# 68               Touille            Touille      NaN  43.0803  0.9736  France
# 99                Tornay             Tornay      NaN  47.7008  5.6064  France
# 138          TignÃ©court         Tignecourt      NaN  48.0433  5.8931  France
# 145    Toulon-sur-Allier  Toulon-sur-Allier   Toulon  46.5178  3.3592  France
# 150         La TruchÃ¨re        La Truchere      NaN  46.5158  4.9514  France
# ...                  ...                ...      ...      ...     ...     ...
# 58927      Trosly-Breuil      Trosly-Breuil   Trosly  49.4003  2.9889  France
# 58939         Tramecourt         Tramecourt      NaN  50.4642  2.1508  France
# 58963            Trancis            Trancis      NaN  45.3500  2.4833  France
# 58997    Wallers-TrÃ©lon     Wallers-Trelon      NaN  50.0639  4.1712  France
# 59063            Taillis            Taillis      NaN  48.1889 -1.2389  France
#
# ...

# %%
data.loc[data['city'].str.contains('I')] # I starting cities are displayed
# Out:
#                          city            city_ascii         city_alt      lat  \
# 142                    Infray                Infray          Hinfray  49.9838
# 214       LâIsle-sur-Serein     L'Isle-sur-Serein         LâIsle  47.5878
# 278           Saint-Inglevert       Saint-Inglevert  Saint-Inglebert  50.8750
# 367                     Ilhet                 Ilhet              NaN  42.9639
# 621                  Ispagnac              Ispagnac              NaN  44.3706
# ...                       ...                   ...              ...      ...
# 58723                  Illats                Illats              NaN  44.5975
# 58745  MÃ©ziÃ¨res-sur-Issoire  Mezieres-sur-Issoire       MÃ©ziÃ¨res  46.1075
# 58839                LâIsle                L'Isle              NaN  47.9262
# 58840                LâIsle                L'Isle              NaN  46.8793
# 58892                 IsÃ´mes                Isomes              NaN  47.6461
#
# ...
